# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# # FIME
# ## Análisis de Datos y Visualización
#
# ## VERDUZCO RAMIREZ JESUS ALBERTO
#
# ## Paola Berenice Robles Becerra
#
# ## S4-P1-U1-AC-O4
#
# ## *Exploratory Analysis of the Cars Dataset*
#
# ##

# %% [markdown]
# ## Personal Reflection:
#
# This activity has been a great opportunity for me to improve my skills in the domain of data science. By following the steps provided, I was able to download a dataset, rename it, and upload it to Jupyter Notebook. I learned how to read a CSV file using Pandas, and how to display the first and last few rows of the dataset using the head() and tail() methods.
#
# One of the most important skills I learned during this activity was how to handle missing data. I used the replace() method to replace all the "?" values in the dataset with NaN values. This allowed me to clean the dataset and prepare it for further analysis.
#
# I also learned how to rename columns in a dataset using the rename() method. I renamed the "*city-mpg*" and "*highway-mpg*" columns to "*city-kpl*" and "*highway-kpl*" respectively, and added new columns to the dataset.
#
# The most challenging part of this activity was converting the values in the "city-mpg" and "*highway-mpg*" columns from miles per gallon to kilometers per liter. I had to investigate the English to MKS measurement system conversion tables and use Pandas commands to perform the conversion. However, this challenge helped me to improve my problem-solving skills and learn new techniques for data manipulation.
#
# Overall, this activity has been a valuable learning experience for me. It has helped me to improve my skills in data handling, data cleaning, and data manipulation using Pandas. I am now more confident in my ability to work with datasets and perform data analysis tasks.

# %% [markdown]
# ## Five things I have learned with the development of this activity:
#
# 1. How to download a dataset from a remote server and save it to a local repository on my PC.
# 2. How to rename a file extension from .data to .csv using the command prompt.
# 3. How to read a CSV file using Pandas and display the first and last few rows of the dataset.
# 4. How to handle missing data in a dataset using the replace() method in Pandas.
# 5. How to rename columns in a dataset using the rename() method in Pandas and add new columns to the dataset.
#
# Additionally, I learned how to convert values from one measurement system to another using Pandas commands. This activity helped me to improve my skills in data handling, data cleaning, and data manipulation using Pandas. I am now more confident in my ability to work with datasets and perform data analysis tasks.

# %%
import pandas as pd

# %%
df = pd.read_csv('auto.csv')

# %%
#exploración inicial
df.head()
df.tail()
# Out:
#      3   ? alfa-romero     gas    std   two convertible  rwd  front  88.60  \
# 199 -1  95       volvo     gas    std  four       sedan  rwd  front  109.1
# 200 -1  95       volvo     gas  turbo  four       sedan  rwd  front  109.1
# 201 -1  95       volvo     gas    std  four       sedan  rwd  front  109.1
# 202 -1  95       volvo  diesel  turbo  four       sedan  rwd  front  109.1
# 203 -1  95       volvo     gas  turbo  four       sedan  rwd  front  109.1
#
#      ...  130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 199  ...  141  mpfi  3.78  3.15   9.5  114  5400  23  28  16845
# 200  ...  141  mpfi  3.78  3.15   8.7  160  5300  19  25  19045
# 201  ...  173  mpfi  3.58  2.87   8.8  134  5500  18  23  21485
# 202  ...  145   idi  3.01  3.40  23.0  106  4800  26  27  22470
# 203  ...  141  mpfi  3.78  3.15   9.5  114  5400  19  25  22625
#
# [5 rows x 26 columns]

# %%
# Lista de columnas del dataframe
headsneme = ["symboling","normalized-losses","make","fuel-type","aspiration",
                "num-of-doors","body- style", "drive-wheels","engine-location",
                "wheel-base","length","width","height","curb-weight","engine-type",
                "num-of-cylinders", "engine-size","fuel-system","bore","stroke",
                "compression-ratio","horsepower", "peak- rpm","city-mpg","highway-mpg","price"]

# %%
df.columns = headsneme
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#    body- style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
#Reemplazar los valores "?" por NaN
import numpy as np
df.replace("?", np.NaN)
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#    body- style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#    body- style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1    hatchback          rwd           front        94.5  ...          152
# 2        sedan          fwd           front        99.8  ...          109
# 3        sedan          4wd           front        99.4  ...          136
# 4        sedan          fwd           front        99.8  ...          136
#
# ...

# %%
# remplazar las columnas "city-mpg", "highway-mpg", a "city-kpl", "highway-kpl"

df.rename(columns={"city-mpg":"city-kpl", "highway-mpg":"highway-kpl"}, inplace=True)
df["city-kpl"] = .43*df["city-kpl"]
df["highway-kpl"] = .43*df["highway-kpl"]
print(df['highway-kpl'], df['city-kpl'])
df.head()
# Out:
# 0      11.61
# 1      11.18
# 2      12.90
# 3       9.46
# 4      10.75
#        ...
# 199    12.04
# 200    10.75
# 201     9.89
# 202    11.61
# 203    10.75
# Name: highway-kpl, Length: 204, dtype: float64 0       9.03
# 1       8.17
# 2      10.32
# 3       7.74
# 4       8.17
#        ...
# 199     9.89
# 200     8.17
# 201     7.74
# 202    11.18
# 203     8.17
# Name: city-kpl, Length: 204, dtype: float64
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#    body- style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %% [markdown]
# # Medidas de tendencia central
#
# Las medidas de tendencia central de un dataset estan representados basicamente por tres parametros:
# + la media aritmetica o promedio
# + la moda
# + la desviación estandar
